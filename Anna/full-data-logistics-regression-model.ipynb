# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
data = pd.read_csv(os.path.join('Invistico_Airline.csv'))
data
# Out:
#         satisfaction  Gender  Customer Type  Age  Type of Travel  Class  \
# 0          satisfied       0              0   47               1      2
# 1          satisfied       0              0   55               1      1
# 2          satisfied       0              0   59               1      2
# 3          satisfied       0              0   66               1      2
# 4          satisfied       0              0   63               1      2
# ...              ...     ...            ...  ...             ...    ...
# 119606     satisfied       1              0   44               0      0
# 119607  dissatisfied       0              0   57               1      2
# 119608     satisfied       0              0   45               0      0
# 119609     satisfied       1              0   46               0      0
# 119610  dissatisfied       1              1   42               0      0
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0                    50             4                                  2
# 1                    50             4                                  4
# 2                    50             4                                  5
# 3                    50             1                                  1
# 4                    50             4                                  3
# ...                 ...           ...                                ...
# 119606             6907             5                                  5
# 119607             6924             3                                  4
# 119608             6948             1                                  1
# 119609             6950             1                                  1
# 119610             6951             2                                  2
#
#         Food and drink  ...  Online support  Ease of Online booking  \
# 0                    4  ...               3                       3
# 1                    4  ...               5                       5
# 2                    5  ...               4                       4
# 3                    1  ...               4                       4
# 4                    3  ...               4                       4
# ...                ...  ...             ...                     ...
# 119606               5  ...               4                       3
# 119607               3  ...               3                       3
# 119608               1  ...               1                       3
# 119609               1  ...               4                       1
# 119610               2  ...               1                       3
#
#         On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                      4                 1                 3                2
# 1                      3                 4                 3                4
# 2                      4                 4                 5                5
# 3                      3                 3                 4                3
# 4                      4                 4                 4                3
# ...                  ...               ...               ...              ...
# 119606                 2                 3                 4                4
# 119607                 1                 5                 1                3
# 119608                 3                 5                 4                1
# 119609                 3                 5                 5                4
# 119610                 3                 4                 5                1
#
#         Cleanliness  Online boarding  Departure Delay in Minutes  \
# 0                 4                3                           0
# 1                 4                5                           0
# 2                 4                4                           0
# 3                 5                4                           0
# 4                 4                2                           0
# ...             ...              ...                         ...
# 119606            4                4                           0
# 119607            3                3                          12
# 119608            3                1                           0
# 119609            3                4                           0
# 119610            4                1                           1
#
#         Arrival Delay in Minutes
# 0                            0.0
# 1                            0.0
# 2                            3.0
# 3                            0.0
# 4                            0.0
# ...                          ...
# 119606                       0.0
# 119607                      17.0
# 119608                      13.0
# 119609                       0.0
# 119610                      25.0
#
# [119611 rows x 23 columns]

# %%
data2 = data.dropna(how='any')
data2
# Out:
#         satisfaction  Gender  Customer Type  Age  Type of Travel  Class  \
# 0          satisfied       0              0   47               1      2
# 1          satisfied       0              0   55               1      1
# 2          satisfied       0              0   59               1      2
# 3          satisfied       0              0   66               1      2
# 4          satisfied       0              0   63               1      2
# ...              ...     ...            ...  ...             ...    ...
# 119606     satisfied       1              0   44               0      0
# 119607  dissatisfied       0              0   57               1      2
# 119608     satisfied       0              0   45               0      0
# 119609     satisfied       1              0   46               0      0
# 119610  dissatisfied       1              1   42               0      0
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0                    50             4                                  2
# 1                    50             4                                  4
# 2                    50             4                                  5
# 3                    50             1                                  1
# 4                    50             4                                  3
# ...                 ...           ...                                ...
# 119606             6907             5                                  5
# 119607             6924             3                                  4
# 119608             6948             1                                  1
# 119609             6950             1                                  1
# 119610             6951             2                                  2
#
#         Food and drink  ...  Online support  Ease of Online booking  \
# 0                    4  ...               3                       3
# 1                    4  ...               5                       5
# 2                    5  ...               4                       4
# 3                    1  ...               4                       4
# 4                    3  ...               4                       4
# ...                ...  ...             ...                     ...
# 119606               5  ...               4                       3
# 119607               3  ...               3                       3
# 119608               1  ...               1                       3
# 119609               1  ...               4                       1
# 119610               2  ...               1                       3
#
#         On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                      4                 1                 3                2
# 1                      3                 4                 3                4
# 2                      4                 4                 5                5
# 3                      3                 3                 4                3
# 4                      4                 4                 4                3
# ...                  ...               ...               ...              ...
# 119606                 2                 3                 4                4
# 119607                 1                 5                 1                3
# 119608                 3                 5                 4                1
# 119609                 3                 5                 5                4
# 119610                 3                 4                 5                1
#
#         Cleanliness  Online boarding  Departure Delay in Minutes  \
# 0                 4                3                           0
# 1                 4                5                           0
# 2                 4                4                           0
# 3                 5                4                           0
# 4                 4                2                           0
# ...             ...              ...                         ...
# 119606            4                4                           0
# 119607            3                3                          12
# 119608            3                1                           0
# 119609            3                4                           0
# 119610            4                1                           1
#
#         Arrival Delay in Minutes
# 0                            0.0
# 1                            0.0
# 2                            3.0
# 3                            0.0
# 4                            0.0
# ...                          ...
# 119606                       0.0
# 119607                      17.0
# 119608                      13.0
# 119609                       0.0
# 119610                      25.0
#
# [119255 rows x 23 columns]

# %%
# Assign X (data) and y (target)
X = data2.drop("satisfaction", axis=1)
y = data2["satisfaction"]
print(X.shape, y.shape)
# Out:
# (119255, 22) (119255,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

length = len(X_train)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(max_iter=length)
classifier
# Out:
# LogisticRegression(max_iter=89441)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=89441)

# %%
classifier.coef_
# Out:
# array([[-1.12315280e+00, -2.79685379e+00, -5.04825762e-03,
#         -1.16091245e+00, -3.16673826e-01, -8.23632309e-05,
#          5.76260955e-01, -4.43363770e-01,  2.28022463e-01,
#         -6.73924480e-02, -9.02957233e-02,  8.57191883e-01,
#          7.59480392e-02,  2.25155769e-01,  3.77102601e-01,
#          2.98229626e-01,  1.60254645e-01,  3.09552951e-01,
#          1.26404127e-01,  2.23696489e-01,  3.29172651e-03,
#         -7.92498344e-03]])

# %%
feature_names = list(X.columns)

# %%
pip install eli5
# Out:
# Requirement already satisfied: eli5 in c:\users\jingd\anaconda3\envs\pythonadv\lib\site-packages (0.11.0)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\jingd\anaconda3\envs\pythonadv\lib\site-packages (from eli5) (0.8.9)
# Requirement already satisfied: graphviz in c:\users\jingd\anaconda3\envs\pythonadv\lib\site-packages (from eli5) (0.16)
# Requirement already satisfied: attrs>16.0.0 in c:\users\jingd\anaconda3\envs\pythonadv\lib\site-packages (from eli5) (21.2.0)
# Requirement already satisfied: scipy in c:\users\jingd\anaconda3\envs\pythonadv\lib\site-packages (from eli5) (1.4.1)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\jingd\anaconda3\envs\pythonadv\lib\site-packages (from eli5) (1.19.2)
# Requirement already satisfied: six in c:\users\jingd\anaconda3\envs\pythonadv\lib\site-packages (from eli5) (1.15.0)
# Requirement already satisfied: scikit-learn>=0.20 in c:\users\jingd\anaconda3\envs\pythonadv\lib\site-packages (from eli5) (0.24.2)
# Requirement already satisfied: jinja2 in c:\users\jingd\anaconda3\envs\pythonadv\lib\site-packages (from eli5) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\jingd\anaconda3\envs\pythonadv\lib\site-packages (from scikit-learn>=0.20->eli5) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jingd\anaconda3\envs\pythonadv\lib\site-packages (from scikit-learn>=0.20->eli5) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in c:\users\jingd\anaconda3\envs\pythonadv\lib\site-packages (from jinja2->eli5) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import eli5
eli5.show_weights(classifier, feature_names = feature_names)
# Out:
# Using TensorFlow backend.
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=satisfied
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.857
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Inflight entertainment
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.576
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Seat comfort
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.52%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.377
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         On-board service
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.310
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Checkin service
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.298
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Leg room service
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.228
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Food and drink
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.27%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.225
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Ease of Online booking
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.224
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Online boarding
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.64%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.160
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Baggage handling
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.126
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Cleanliness
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.076
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Online support
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 99.19%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 1 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.83%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 2 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.008
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Arrival Delay in Minutes
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.067
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Gate location
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.090
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Inflight wifi service
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 97.81%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.317
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Class
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 97.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.443
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Departure/Arrival time convenient
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 94.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.123
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Gender
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 94.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.161
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Type of Travel
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.797
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Customer Type
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -7.445
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.8647823705012243
# Testing Data Score: 0.8646944388542296

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['satisfied' 'satisfied' 'dissatisfied' 'dissatisfied' 'satisfied'
#  'satisfied' 'satisfied' 'dissatisfied' 'dissatisfied' 'satisfied']
# First 10 Actual labels: ['satisfied', 'satisfied', 'satisfied', 'dissatisfied', 'satisfied', 'satisfied', 'satisfied', 'dissatisfied', 'satisfied', 'satisfied']

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#           Prediction        Actual
# 11398      satisfied     satisfied
# 105733     satisfied     satisfied
# 83618   dissatisfied     satisfied
# 81612   dissatisfied  dissatisfied
# 1945       satisfied     satisfied
# ...              ...           ...
# 65946   dissatisfied  dissatisfied
# 113196     satisfied     satisfied
# 12931      satisfied  dissatisfied
# 77404   dissatisfied     satisfied
# 40827   dissatisfied  dissatisfied
#
# [29814 rows x 2 columns]

# %%
import joblib
joblib.dump(classifier,'fulldata.pkl')
# Out:
# ['fulldata.pkl']

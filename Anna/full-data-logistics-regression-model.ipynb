# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
data = pd.read_csv(os.path.join('Invistico_Airline.csv'))
data
# Out:
#         satisfaction  Gender  Customer Type  Age  Type of Travel  Class  \
# 0          satisfied       0              0   47               1      2
# 1          satisfied       0              0   55               1      1
# 2          satisfied       0              0   59               1      2
# 3          satisfied       0              0   66               1      2
# 4          satisfied       0              0   63               1      2
# ...              ...     ...            ...  ...             ...    ...
# 119606     satisfied       1              0   44               0      0
# 119607  dissatisfied       0              0   57               1      2
# 119608     satisfied       0              0   45               0      0
# 119609     satisfied       1              0   46               0      0
# 119610  dissatisfied       1              1   42               0      0
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# ...

# %%
data2 = data.dropna(how='any')
data2
# Out:
#         satisfaction  Gender  Customer Type  Age  Type of Travel  Class  \
# 0          satisfied       0              0   47               1      2
# 1          satisfied       0              0   55               1      1
# 2          satisfied       0              0   59               1      2
# 3          satisfied       0              0   66               1      2
# 4          satisfied       0              0   63               1      2
# ...              ...     ...            ...  ...             ...    ...
# 119606     satisfied       1              0   44               0      0
# 119607  dissatisfied       0              0   57               1      2
# 119608     satisfied       0              0   45               0      0
# 119609     satisfied       1              0   46               0      0
# 119610  dissatisfied       1              1   42               0      0
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# ...

# %%
# Assign X (data) and y (target)
X = data2.drop("satisfaction", axis=1)
y = data2["satisfaction"]
print(X.shape, y.shape)
# Out:
# (119255, 22) (119255,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

length = len(X_train)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(max_iter=length)
classifier
# Out:
# LogisticRegression(max_iter=89441)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=89441)

# %%
classifier.coef_
# Out:
# array([[-9.18839024e-01, -2.28455613e+00, -3.72390137e-03,
#         -8.92714436e-01, -3.98166210e-01, -9.15891804e-05,
#          5.74411854e-01, -4.48127137e-01,  1.92451482e-01,
#         -4.37844816e-02, -1.04859407e-01,  8.78432066e-01,
#          8.32524110e-02,  2.97813674e-01,  3.67451263e-01,
#          2.89520024e-01,  1.13227058e-01,  3.23954640e-01,
#          7.60329595e-02,  1.94295019e-01,  2.59423394e-03,
#         -7.06070999e-03]])

# %%
feature_names = list(X.columns)

# %%
pip install eli5
# Out:
# ...
#   Using cached eli5-0.11.0-py2.py3-none-any.whl (106 kB)
# ...
#   Using cached tabulate-0.8.9-py3-none-any.whl (25 kB)
# ...
#   Using cached graphviz-0.16-py2.py3-none-any.whl (19 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import eli5
eli5.show_weights(classifier, feature_names = feature_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=satisfied
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
# ...

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.8648159121655616
# Testing Data Score: 0.8650298517475011

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['satisfied' 'satisfied' 'dissatisfied' 'dissatisfied' 'satisfied'
#  'satisfied' 'satisfied' 'dissatisfied' 'dissatisfied' 'satisfied']
# First 10 Actual labels: ['satisfied', 'satisfied', 'satisfied', 'dissatisfied', 'satisfied', 'satisfied', 'satisfied', 'dissatisfied', 'satisfied', 'satisfied']

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#           Prediction        Actual
# 11398      satisfied     satisfied
# 105733     satisfied     satisfied
# 83618   dissatisfied     satisfied
# 81612   dissatisfied  dissatisfied
# 1945       satisfied     satisfied
# ...              ...           ...
# 65946   dissatisfied  dissatisfied
# 113196     satisfied     satisfied
# 12931      satisfied  dissatisfied
# 77404   dissatisfied     satisfied
# 40827   dissatisfied  dissatisfied
#
# [29814 rows x 2 columns]

# %%
import joblib
joblib.dump(classifier,'fulldata.pkl')
# Out:
# ['fulldata.pkl']

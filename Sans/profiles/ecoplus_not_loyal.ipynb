# %%
# Importing dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Importing CSV
df = pd.read_csv('Invistico_Airline.csv')
df.head()
# Out:
#   satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Female  Loyal Customer   47  Personal Travel       Eco
# 1    satisfied  Female  Loyal Customer   55  Personal Travel  Eco Plus
# 2    satisfied  Female  Loyal Customer   59  Personal Travel       Eco
# 3    satisfied  Female  Loyal Customer   66  Personal Travel       Eco
# 4    satisfied  Female  Loyal Customer   63  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0               50             4                                  2
# 1               50             4                                  4
# 2               50             4                                  5
# 3               50             1                                  1
# 4               50             4                                  3
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# 0               4  ...               3                       3
# 1               4  ...               5                       5
# 2               5  ...               4                       4
# 3               1  ...               4                       4
# 4               3  ...               4                       4
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 1                 3                2
# 1                 3                 4                 3                4
# 2                 4                 4                 5                5
# 3                 3                 3                 4                3
# 4                 4                 4                 4                3
#
#    Cleanliness  Online boarding  Departure Delay in Minutes  \
# 0            4                3                           0
# 1            4                5                           0
# 2            4                4                           0
# 3            5                4                           0
# 4            4                2                           0
#
#    Arrival Delay in Minutes
# 0                       0.0
# 1                       0.0
# 2                       3.0
# 3                       0.0
# 4                       0.0
#
# [5 rows x 23 columns]

# %%
# Filtering dataframe for disloyal & Eco plus customers
data = df[(df["Class"]=="Eco Plus")&(df["Customer Type"]=="disloyal Customer") ]
data
# Out:
#         satisfaction  Gender      Customer Type  Age   Type of Travel  \
# 6309    dissatisfied  Female  disloyal Customer   79  Business travel
# 18207   dissatisfied  Female  disloyal Customer   33  Business travel
# 18223   dissatisfied  Female  disloyal Customer   42  Business travel
# 19268   dissatisfied  Female  disloyal Customer   43  Business travel
# 19439   dissatisfied  Female  disloyal Customer   55  Business travel
# ...              ...     ...                ...  ...              ...
# 116069  dissatisfied    Male  disloyal Customer   29  Business travel
# 116143  dissatisfied  Female  disloyal Customer   30  Business travel
# 116486  dissatisfied    Male  disloyal Customer   30  Business travel
# 117207     satisfied  Female  disloyal Customer   17  Business travel
# 118518  dissatisfied  Female  disloyal Customer   12  Business travel
#
#            Class  Flight Distance  Seat comfort  \
# 6309    Eco Plus              356             4
# 18207   Eco Plus              854             3
# 18223   Eco Plus              855             2
# 19268   Eco Plus              904             3
# 19439   Eco Plus              912             4
# ...          ...              ...           ...
# 116069  Eco Plus             4054             3
# 116143  Eco Plus             4069             3
# 116486  Eco Plus             4150             2
# 117207  Eco Plus             4354             5
# 118518  Eco Plus             4907             3
#
#         Departure/Arrival time convenient  Food and drink  ...  \
# 6309                                    4               4  ...
# 18207                                   3               3  ...
# 18223                                   2               2  ...
# 19268                                   3               3  ...
# 19439                                   4               4  ...
# ...                                   ...             ...  ...
# 116069                                  3               3  ...
# 116143                                  3               3  ...
# 116486                                  2               2  ...
# 117207                                  5               5  ...
# 118518                                  2               3  ...
#
#         Online support  Ease of Online booking  On-board service  \
# 6309                 5                       4                 4
# 18207                3                       3                 2
# 18223                5                       5                 3
# 19268                5                       4                 3
# 19439                5                       4                 5
# ...                ...                     ...               ...
# 116069               4                       4                 3
# 116143               3                       1                 2
# 116486               5                       5                 3
# 117207               2                       2                 5
# 118518               4                       1                 4
#
#         Leg room service  Baggage handling  Checkin service  Cleanliness  \
# 6309                   4                 4                1            4
# 18207                  1                 3                4            3
# 18223                  4                 4                4            2
# 19268                  2                 5                5            5
# 19439                  3                 4                5            1
# ...                  ...               ...              ...          ...
# 116069                 5                 3                4            4
# 116143                 2                 3                3            1
# 116486                 2                 2                5            5
# 117207                 1                 3                1            2
# 118518                 3                 4                4            2
#
#         Online boarding  Departure Delay in Minutes  Arrival Delay in Minutes
# 6309                  1                           4                       0.0
# 18207                 3                          98                      84.0
# 18223                 5                           0                       0.0
# 19268                 4                           0                       0.0
# 19439                 4                           0                       0.0
# ...                 ...                         ...                       ...
# 116069                4                           7                       0.0
# 116143                3                           8                      20.0
# 116486                5                           0                       0.0
# 117207                2                          91                      75.0
# 118518                4                          12                       0.0
#
# [814 rows x 23 columns]

# %%
# Creating new dataframe from the filtered dataframe and dropping all demographic data
newdf = data.drop(["satisfaction", "Gender", "Customer Type", "Age", "Type of Travel","Class", "Flight Distance" ], axis=1)
feature_names = newdf.columns
newdf.head()
# Out:
#        Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 6309              4                                  4               4
# 18207             3                                  3               3
# 18223             2                                  2               2
# 19268             3                                  3               3
# 19439             4                                  4               4
#
#        Gate location  Inflight wifi service  Inflight entertainment  \
# 6309               2                      5                       3
# 18207              3                      3                       3
# 18223              4                      5                       2
# 19268              2                      4                       3
# 19439              3                      4                       4
#
#        Online support  Ease of Online booking  On-board service  \
# 6309                5                       4                 4
# 18207               3                       3                 2
# 18223               5                       5                 3
# 19268               5                       4                 3
# 19439               5                       4                 5
#
#        Leg room service  Baggage handling  Checkin service  Cleanliness  \
# 6309                  4                 4                1            4
# 18207                 1                 3                4            3
# 18223                 4                 4                4            2
# 19268                 2                 5                5            5
# 19439                 3                 4                5            1
#
#        Online boarding  Departure Delay in Minutes  Arrival Delay in Minutes
# 6309                 1                           4                       0.0
# 18207                3                          98                      84.0
# 18223                5                           0                       0.0
# 19268                4                           0                       0.0
# 19439                4                           0                       0.0

# %%
# Assigning target (y variable)
target = data["satisfaction"]
target_names = ["satisfied", "dissatisfied"]

# %%
# Checking nulls
newdf.isnull().sum()
# Out:
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             2
# dtype: int64

# %%
# Splitting the dataset into test and train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(newdf, target, random_state=42)

# %%
# Importing imputer and training the dataset for nan values
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X_train)
X_train = imputer.transform(X_train)

# %%
X_test = imputer.transform(X_test)

# %%
feature_names
lst = list(feature_names)
lst
# Out:
# ['Seat comfort',
#  'Departure/Arrival time convenient',
#  'Food and drink',
#  'Gate location',
#  'Inflight wifi service',
#  'Inflight entertainment',
#  'Online support',
#  'Ease of Online booking',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Cleanliness',
#  'Online boarding',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes']

# %%
# Importing Logistic Regression module
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(max_iter=4000000)
classifier
# Out:
# LogisticRegression(max_iter=4000000)

# %%
# Training the dataset
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=4000000)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9721311475409836
# Testing Data Score: 0.9754901960784313

# %%
# Testing the model
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#           Prediction        Actual
# 44412   dissatisfied  dissatisfied
# 76263   dissatisfied  dissatisfied
# 42476   dissatisfied  dissatisfied
# 48895   dissatisfied  dissatisfied
# 70822   dissatisfied  dissatisfied
# ...              ...           ...
# 50112   dissatisfied  dissatisfied
# 29694   dissatisfied  dissatisfied
# 53053   dissatisfied  dissatisfied
# 37617   dissatisfied  dissatisfied
# 110548  dissatisfied  dissatisfied
#
# [204 rows x 2 columns]

# %%
# Checking feature importance
import eli5
eli5.show_weights(classifier, feature_names=lst)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=satisfied
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.923
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Seat comfort
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.228
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Food and drink
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.81%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.439
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Baggage handling
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.64%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.221
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Checkin service
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.178
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Online boarding
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.145
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Inflight wifi service
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.108
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         On-board service
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.045
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Departure/Arrival time convenient
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.86%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.009
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Arrival Delay in Minutes
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.020
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Departure Delay in Minutes
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.101
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Online support
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.133
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Cleanliness
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 98.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.292
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Leg room service
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 98.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.340
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Ease of Online booking
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 97.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.486
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Inflight entertainment
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 96.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.975
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Gate location
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.346
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %%
# Checking coorelation between variables
import seaborn as sns
cor = newdf.corr()
plt.figure(figsize = (20,6))
sns.heatmap(cor, annot=True)
# Out:
# <AxesSubplot:>

# %%
# Creating a copy of the original dataset
improved = data.copy()
improved
# Out:
#         satisfaction  Gender      Customer Type  Age   Type of Travel  \
# 6309    dissatisfied  Female  disloyal Customer   79  Business travel
# 18207   dissatisfied  Female  disloyal Customer   33  Business travel
# 18223   dissatisfied  Female  disloyal Customer   42  Business travel
# 19268   dissatisfied  Female  disloyal Customer   43  Business travel
# 19439   dissatisfied  Female  disloyal Customer   55  Business travel
# ...              ...     ...                ...  ...              ...
# 116069  dissatisfied    Male  disloyal Customer   29  Business travel
# 116143  dissatisfied  Female  disloyal Customer   30  Business travel
# 116486  dissatisfied    Male  disloyal Customer   30  Business travel
# 117207     satisfied  Female  disloyal Customer   17  Business travel
# 118518  dissatisfied  Female  disloyal Customer   12  Business travel
#
#            Class  Flight Distance  Seat comfort  \
# 6309    Eco Plus              356             4
# 18207   Eco Plus              854             3
# 18223   Eco Plus              855             2
# 19268   Eco Plus              904             3
# 19439   Eco Plus              912             4
# ...          ...              ...           ...
# 116069  Eco Plus             4054             3
# 116143  Eco Plus             4069             3
# 116486  Eco Plus             4150             2
# 117207  Eco Plus             4354             5
# 118518  Eco Plus             4907             3
#
#         Departure/Arrival time convenient  Food and drink  ...  \
# 6309                                    4               4  ...
# 18207                                   3               3  ...
# 18223                                   2               2  ...
# 19268                                   3               3  ...
# 19439                                   4               4  ...
# ...                                   ...             ...  ...
# 116069                                  3               3  ...
# 116143                                  3               3  ...
# 116486                                  2               2  ...
# 117207                                  5               5  ...
# 118518                                  2               3  ...
#
#         Online support  Ease of Online booking  On-board service  \
# 6309                 5                       4                 4
# 18207                3                       3                 2
# 18223                5                       5                 3
# 19268                5                       4                 3
# 19439                5                       4                 5
# ...                ...                     ...               ...
# 116069               4                       4                 3
# 116143               3                       1                 2
# 116486               5                       5                 3
# 117207               2                       2                 5
# 118518               4                       1                 4
#
#         Leg room service  Baggage handling  Checkin service  Cleanliness  \
# 6309                   4                 4                1            4
# 18207                  1                 3                4            3
# 18223                  4                 4                4            2
# 19268                  2                 5                5            5
# 19439                  3                 4                5            1
# ...                  ...               ...              ...          ...
# 116069                 5                 3                4            4
# 116143                 2                 3                3            1
# 116486                 2                 2                5            5
# 117207                 1                 3                1            2
# 118518                 3                 4                4            2
#
#         Online boarding  Departure Delay in Minutes  Arrival Delay in Minutes
# 6309                  1                           4                       0.0
# 18207                 3                          98                      84.0
# 18223                 5                           0                       0.0
# 19268                 4                           0                       0.0
# 19439                 4                           0                       0.0
# ...                 ...                         ...                       ...
# 116069                4                           7                       0.0
# 116143                3                           8                      20.0
# 116486                5                           0                       0.0
# 117207                2                          91                      75.0
# 118518                4                          12                       0.0
#
# [814 rows x 23 columns]

# %%
# Improving the scores for the top 3 variables
improved['Food and drink improved'] = np.where((improved['Food and drink'] <= 3),  improved['Food and drink']+1, improved['Food and drink'])
improved['Seat comfort improved'] = np.where((improved['Seat comfort'] <= 3),  improved['Seat comfort']+1, improved['Seat comfort'])
improved['Baggage handling improved'] = np.where((improved['Baggage handling'] <= 3),  improved['Baggage handling']+1, improved['Baggage handling'])

# %%
#improved.to_csv("test.csv")
improved
# Out:
#         satisfaction  Gender      Customer Type  Age   Type of Travel  \
# 6309    dissatisfied  Female  disloyal Customer   79  Business travel
# 18207   dissatisfied  Female  disloyal Customer   33  Business travel
# 18223   dissatisfied  Female  disloyal Customer   42  Business travel
# 19268   dissatisfied  Female  disloyal Customer   43  Business travel
# 19439   dissatisfied  Female  disloyal Customer   55  Business travel
# ...              ...     ...                ...  ...              ...
# 116069  dissatisfied    Male  disloyal Customer   29  Business travel
# 116143  dissatisfied  Female  disloyal Customer   30  Business travel
# 116486  dissatisfied    Male  disloyal Customer   30  Business travel
# 117207     satisfied  Female  disloyal Customer   17  Business travel
# 118518  dissatisfied  Female  disloyal Customer   12  Business travel
#
#            Class  Flight Distance  Seat comfort  \
# 6309    Eco Plus              356             4
# 18207   Eco Plus              854             3
# 18223   Eco Plus              855             2
# 19268   Eco Plus              904             3
# 19439   Eco Plus              912             4
# ...          ...              ...           ...
# 116069  Eco Plus             4054             3
# 116143  Eco Plus             4069             3
# 116486  Eco Plus             4150             2
# 117207  Eco Plus             4354             5
# 118518  Eco Plus             4907             3
#
#         Departure/Arrival time convenient  Food and drink  ...  \
# 6309                                    4               4  ...
# 18207                                   3               3  ...
# 18223                                   2               2  ...
# 19268                                   3               3  ...
# 19439                                   4               4  ...
# ...                                   ...             ...  ...
# 116069                                  3               3  ...
# 116143                                  3               3  ...
# 116486                                  2               2  ...
# 117207                                  5               5  ...
# 118518                                  2               3  ...
#
#         Leg room service  Baggage handling  Checkin service  Cleanliness  \
# 6309                   4                 4                1            4
# 18207                  1                 3                4            3
# 18223                  4                 4                4            2
# 19268                  2                 5                5            5
# 19439                  3                 4                5            1
# ...                  ...               ...              ...          ...
# 116069                 5                 3                4            4
# 116143                 2                 3                3            1
# 116486                 2                 2                5            5
# 117207                 1                 3                1            2
# 118518                 3                 4                4            2
#
#         Online boarding  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 6309                  1                           4                       0.0
# 18207                 3                          98                      84.0
# 18223                 5                           0                       0.0
# 19268                 4                           0                       0.0
# 19439                 4                           0                       0.0
# ...                 ...                         ...                       ...
# 116069                4                           7                       0.0
# 116143                3                           8                      20.0
# 116486                5                           0                       0.0
# 117207                2                          91                      75.0
# 118518                4                          12                       0.0
#
#         Food and drink improved  Seat comfort improved  \
# 6309                          4                      4
# 18207                         4                      4
# 18223                         3                      3
# 19268                         4                      4
# 19439                         4                      4
# ...                         ...                    ...
# 116069                        4                      4
# 116143                        4                      4
# 116486                        3                      3
# 117207                        5                      5
# 118518                        4                      4
#
#         Baggage handling improved
# 6309                            4
# 18207                           4
# 18223                           4
# 19268                           5
# 19439                           4
# ...                           ...
# 116069                          4
# 116143                          4
# 116486                          3
# 117207                          4
# 118518                          4
#
# [814 rows x 26 columns]

# %%
# Assigning the dependent variable
y_improved = improved["satisfaction"]

# %%
# Removing all demographic data and assigning to X variable
X_improved = improved.drop(["satisfaction", "Gender", "Customer Type", "Age", "Type of Travel","Class", "Flight Distance", "Inflight entertainment","Seat comfort", "Ease of Online booking" ], axis=1)

X_improved.head()
# Out:
#        Departure/Arrival time convenient  Food and drink  Gate location  \
# 6309                                   4               4              2
# 18207                                  3               3              3
# 18223                                  2               2              4
# 19268                                  3               3              2
# 19439                                  4               4              3
#
#        Inflight wifi service  Online support  On-board service  \
# 6309                       5               5                 4
# 18207                      3               3                 2
# 18223                      5               5                 3
# 19268                      4               5                 3
# 19439                      4               5                 5
#
#        Leg room service  Baggage handling  Checkin service  Cleanliness  \
# 6309                  4                 4                1            4
# 18207                 1                 3                4            3
# 18223                 4                 4                4            2
# 19268                 2                 5                5            5
# 19439                 3                 4                5            1
#
#        Online boarding  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 6309                 1                           4                       0.0
# 18207                3                          98                      84.0
# 18223                5                           0                       0.0
# 19268                4                           0                       0.0
# 19439                4                           0                       0.0
#
#        Food and drink improved  Seat comfort improved  \
# 6309                         4                      4
# 18207                        4                      4
# 18223                        3                      3
# 19268                        4                      4
# 19439                        4                      4
#
#        Baggage handling improved
# 6309                           4
# 18207                          4
# 18223                          4
# 19268                          5
# 19439                          4

# %%
X_improved = imputer.transform(X_improved)

# %%
# Running the model on the improved scores
predictions = classifier.predict(X_improved)
predictions = pd.DataFrame({"Prediction": predictions, "Actual": y_improved})
predictions
# Out:
#           Prediction        Actual
# 6309    dissatisfied  dissatisfied
# 18207      satisfied  dissatisfied
# 18223   dissatisfied  dissatisfied
# 19268   dissatisfied  dissatisfied
# 19439   dissatisfied  dissatisfied
# ...              ...           ...
# 116069  dissatisfied  dissatisfied
# 116143  dissatisfied  dissatisfied
# 116486  dissatisfied  dissatisfied
# 117207     satisfied     satisfied
# 118518  dissatisfied  dissatisfied
#
# [814 rows x 2 columns]

# %%
# Saving the predictions as CSV
predictions.to_csv("not_loyal_ecoplus_improved_ratings.csv")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Invistico_Airline.csv')
df.head()
# Out:
#   satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Female  Loyal Customer   47  Personal Travel       Eco
# 1    satisfied  Female  Loyal Customer   55  Personal Travel  Eco Plus
# 2    satisfied  Female  Loyal Customer   59  Personal Travel       Eco
# 3    satisfied  Female  Loyal Customer   66  Personal Travel       Eco
# 4    satisfied  Female  Loyal Customer   63  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0               50             4                                  2
# 1               50             4                                  4
# 2               50             4                                  5
# 3               50             1                                  1
# 4               50             4                                  3
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# ...

# %%
target = df["satisfaction"]
target_names = ["satisfied", "dissatisfied"]

# %%
data = df.drop(["satisfaction"], axis=1)

data.head()
# Out:
#    Gender   Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0  Female  Loyal Customer   47  Personal Travel       Eco               50
# 1  Female  Loyal Customer   55  Personal Travel  Eco Plus               50
# 2  Female  Loyal Customer   59  Personal Travel       Eco               50
# 3  Female  Loyal Customer   66  Personal Travel       Eco               50
# 4  Female  Loyal Customer   63  Personal Travel       Eco               50
#
#    Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0             4                                  2               4
# 1             4                                  4               4
# 2             4                                  5               5
# 3             1                                  1               1
# 4             4                                  3               3
#
#    Gate location  ...  Online support  Ease of Online booking  \
# ...

# %%
data = pd.get_dummies(data, drop_first=True)
feature_names = data.columns
data.head(20)
# Out:
#     Age  Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0    47               50             4                                  2
# 1    55               50             4                                  4
# 2    59               50             4                                  5
# 3    66               50             1                                  1
# 4    63               50             4                                  3
# 5    54               50             3                                  5
# 6    60               50             4                                  4
# 7    65               50             1                                  2
# 8    53               50             2                                  2
# 9    57               50             2                                  2
# 10   39               50             4                                  4
# 11   43               50             2                                  2
# ...

# %%
data.isnull().sum()
# Out:
# Age                                    0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             356
# Gender_Male                            0
# Customer Type_disloyal Customer        0
# Type of Travel_Personal Travel         0
# Class_Eco                              0
# Class_Eco Plus                         0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
X_train.shape
# Out:
# (89708, 23)

# %%
X_test.shape
# Out:
# (29903, 23)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X_train)
X_train = imputer.transform(X_train)

# %%
X_test = imputer.transform(X_test)

# %%
import pickle
Pkl_Filename = "imputer.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(imputer, file)

# %%
X_test
# Out:
# array([[1.500e+01, 2.548e+03, 2.000e+00, ..., 0.000e+00, 0.000e+00,
#         1.000e+00],
#        [4.900e+01, 1.509e+03, 4.000e+00, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [2.200e+01, 1.424e+03, 2.000e+00, ..., 0.000e+00, 1.000e+00,
#         0.000e+00],
#        ...,
#        [5.300e+01, 2.306e+03, 4.000e+00, ..., 1.000e+00, 0.000e+00,
#         1.000e+00],
#        [4.800e+01, 2.766e+03, 2.000e+00, ..., 1.000e+00, 1.000e+00,
#         0.000e+00],
#        [1.000e+01, 1.776e+03, 3.000e+00, ..., 1.000e+00, 1.000e+00,
#         0.000e+00]])

# %%
feature_names
lst = list(feature_names)
lst
# Out:
# ['Age',
#  'Flight Distance',
#  'Seat comfort',
#  'Departure/Arrival time convenient',
#  'Food and drink',
#  'Gate location',
#  'Inflight wifi service',
#  'Inflight entertainment',
#  'Online support',
#  'Ease of Online booking',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Cleanliness',
#  'Online boarding',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes',
#  'Gender_Male',
#  'Customer Type_disloyal Customer',
#  'Type of Travel_Personal Travel',
#  'Class_Eco',
#  'Class_Eco Plus']

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(max_iter=4000000)
classifier
# Out:
# LogisticRegression(max_iter=4000000)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=4000000)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.8658313639809159
# Testing Data Score: 0.8654315620506303

# %%
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#          Prediction        Actual
# 88936  dissatisfied  dissatisfied
# 35633     satisfied     satisfied
# 32080  dissatisfied  dissatisfied
# 41071  dissatisfied  dissatisfied
# 86517     satisfied     satisfied
# ...             ...           ...
# 2753      satisfied     satisfied
# 84402     satisfied  dissatisfied
# 79070     satisfied     satisfied
# 95594  dissatisfied  dissatisfied
# 50282  dissatisfied  dissatisfied
#
# [29903 rows x 2 columns]

# %%
# get importance
importance = classifier.coef_
importance
# Out:
# array([[-3.59590487e-03, -8.91567954e-05,  5.93522555e-01,
#         -4.45888867e-01,  1.95366049e-01, -6.69100206e-02,
#         -9.58658112e-02,  8.79319578e-01,  9.33182693e-02,
#          2.73613784e-01,  3.64871594e-01,  2.90476333e-01,
#          1.30845470e-01,  3.19995834e-01,  8.84024737e-02,
#          2.00964593e-01,  1.25211120e-03, -5.81039109e-03,
#         -9.48470590e-01, -2.33854947e+00, -9.01269753e-01,
#         -8.24447489e-01, -8.18115376e-01]])

# %%
sorted(zip(importance, feature_names), reverse=True)
# Out:
# [(array([-3.59590487e-03, -8.91567954e-05,  5.93522555e-01, -4.45888867e-01,
#           1.95366049e-01, -6.69100206e-02, -9.58658112e-02,  8.79319578e-01,
#           9.33182693e-02,  2.73613784e-01,  3.64871594e-01,  2.90476333e-01,
#           1.30845470e-01,  3.19995834e-01,  8.84024737e-02,  2.00964593e-01,
#           1.25211120e-03, -5.81039109e-03, -9.48470590e-01, -2.33854947e+00,
#          -9.01269753e-01, -8.24447489e-01, -8.18115376e-01]),
#   'Age')]

# %%
pip install eli5

# %%
import eli5
eli5.show_weights(classifier, feature_names=lst)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=satisfied
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
# ...

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.10.0
# anaconda-project                   0.8.3
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.4.2
# astropy                            4.0.2
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.4
# Babel                              2.8.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# ...

# %%
import pickle

# %%
Pkl_Filename = "output/Pickle_RL_Model.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(classifier, file)

# %%
# Load the Model back from file
with open(Pkl_Filename, 'rb') as file:  
    Pickled_LR_Model = pickle.load(file)

Pickled_LR_Model
# Out:
# LogisticRegression(max_iter=4000000)

# %%
# Use the Reloaded Model to 
# Calculate the accuracy score and predict target values

# Calculate the Score 
score = Pickled_LR_Model.score(X_test, y_test)  
# Print the Score
print("Test score: {0:.2f} %".format(100 * score))  

# Predict the Labels using the reloaded Model
Ypredict = Pickled_LR_Model.predict(X_test)  

Ypredict
# Out:
# Test score: 86.54 %
# array(['dissatisfied', 'satisfied', 'dissatisfied', ..., 'satisfied',
#        'dissatisfied', 'dissatisfied'], dtype=object)

# %%
X_test
# Out:
# array([[1.500e+01, 2.548e+03, 2.000e+00, ..., 0.000e+00, 0.000e+00,
#         1.000e+00],
#        [4.900e+01, 1.509e+03, 4.000e+00, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [2.200e+01, 1.424e+03, 2.000e+00, ..., 0.000e+00, 1.000e+00,
#         0.000e+00],
#        ...,
#        [5.300e+01, 2.306e+03, 4.000e+00, ..., 1.000e+00, 0.000e+00,
#         1.000e+00],
#        [4.800e+01, 2.766e+03, 2.000e+00, ..., 1.000e+00, 1.000e+00,
#         0.000e+00],
#        [1.000e+01, 1.776e+03, 3.000e+00, ..., 1.000e+00, 1.000e+00,
#         0.000e+00]])

# %%
test_data = [None, None, None, None, None, None, '5', '5', '5', '5', '5', '5', '5', None, None, None, None, None, None, None, None, None]
[np.nan if val == None else val for val in test_data]
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]
